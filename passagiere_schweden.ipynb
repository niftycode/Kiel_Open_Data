# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

FILEPATH = "data/kiel_transport_hafen.csv"

# read csv dataset
df = pd.read_csv(FILEPATH, encoding='cp1252', sep=';')

# show first five rows
print(df.head())
# Out:
#     Land Stadt          Kategorie                            Merkmal  Jahr  \
# 0  de-sh  Kiel  transport_verkehr  Passagiere nach Ziel und Herkunft  1996
# 1  de-sh  Kiel  transport_verkehr  Passagiere nach Ziel und Herkunft  1997
# 2  de-sh  Kiel  transport_verkehr  Passagiere nach Ziel und Herkunft  1998
# 3  de-sh  Kiel  transport_verkehr  Passagiere nach Ziel und Herkunft  1999
# 4  de-sh  Kiel  transport_verkehr  Passagiere nach Ziel und Herkunft  2000
#
#    Norwegen  Schweden  Dänemark  Baltikum
# 0    549925    889402    392271     38202
# 1    556398    907359    418995     26808
# 2    561791    817358    424222     26041
# 3    517355    532037    117124     21499
# 4    586610    395964     37603     26714

# %%
# drop na values
df_cleaned = df.dropna()

df_years = df_cleaned['Jahr'].astype(np.uint16)
df_sweden = df_cleaned['Schweden']

x = df_years.values
y = df_sweden.values

fig, ax = plt.subplots()

plt.title("Kieler Hafen\nPassagiere für Schweden (1996 - 2017)", size="x-large")
plt.ylabel("Passagiere (Schweden)", size="x-large")
plt.xlabel("Jahr", size="x-large")

plt.plot(y, "r*-", markersize=6, linewidth=1, color='b')

ax.set_xticks(range(len(x)))
ax.set_xticklabels(x, rotation='vertical')

plt.show()
