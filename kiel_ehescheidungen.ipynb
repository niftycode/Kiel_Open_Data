# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV-Datei lesen (Dataframe => df) erzeugen
csv_data = 'data/kiel_ehescheidungen.csv'
df = pd.read_csv(csv_data, encoding='latin1', sep=';')

# Die ersten fünf Zeilen ausgeben
print(df.head())

# Zeilen mit fehlenden Werten (NaN) entfernen
df_cleaned = df.dropna()

x = df_cleaned['Jahr'].values
y = df_cleaned['Ehescheidungen'].values

# Subplot erstellen
fig, ax = plt.subplots()

# Beschriftungen hinzufügen
plt.title("Ehescheidungen in Kiel", size="x-large")
plt.ylabel("Anzahl", size="x-large")
plt.xlabel("Jahr", size="x-large")

# Aussehen der x-Achse festlegen
ax.set_xticks(range(len(x)))
ax.set_xticklabels(x, rotation='vertical')

# y-Achse, Legende
plt.plot(y, "r*-", markersize=6, linewidth=1, color='r')

plt.show()
# Out:
#     Land Stadt  Jahr    Kategorie         Merkmal  Ehescheidungen
# 0  de-sh  Kiel  1988  Bevölkerung  Ehescheidungen             648
# 1  de-sh  Kiel  1989  Bevölkerung  Ehescheidungen             627
# 2  de-sh  Kiel  1990  Bevölkerung  Ehescheidungen             618
# 3  de-sh  Kiel  1991  Bevölkerung  Ehescheidungen             582
# 4  de-sh  Kiel  1992  Bevölkerung  Ehescheidungen             578
